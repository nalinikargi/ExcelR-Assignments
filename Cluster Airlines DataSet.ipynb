# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import normalize
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_excel(r"C:\Users\DELL\Desktop\Data Science\DS Assignment\Clustering\EastWestAirlines.xlsx",'data')

# %%
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
data2=data.drop(['ID#'],axis=1)
data2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Normalize heterogenous numerical data 
data2_norm=pd.DataFrame(normalize(data2),columns=data2.columns)
data2_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# create dendrogram
plt.figure(figsize = (10,7))
dendrogram = sch.dendrogram(sch.linkage(data2_norm, method='complete'))

# %%
#after cutting 
# create clusters
hc = AgglomerativeClustering(n_clusters = 5,
                             affinity = 'euclidean',
                             linkage = 'ward')

# %%
# save clusters for chart
y_hc = hc.fit_predict(data2_norm)
y_hc
# Out:
# array([4, 2, 2, ..., 2, 4, 2], dtype=int64)

# %%
Clusters = pd.DataFrame(y_hc, columns=['Clusters'])
Clusters
# Out:
#       Clusters
# 0            4
# 1            2
# 2            2
# 3            2
# 4            3
# ...        ...
# 3994         3
# 3995         4
# 3996         2
# 3997         4
# 3998         2
#
# [3999 rows x 1 columns]

# %%
data2['h_clusterid'] = Clusters

# %%
data2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(data2['h_clusterid'],data2['Balance'], c=hc.labels_)

# %% [markdown]
# # Kmeans

# %%
data=pd.read_excel(r"C:\Users\DELL\Desktop\Data Science\DS Assignment\Clustering\EastWestAirlines.xlsx",'data')

# %%
data3=data.drop(['ID#'],axis=1)
data3
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Normalize heterogenous numerical data 
data3_norm=pd.DataFrame(normalize(data3),columns=data3.columns)
data3_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Elbow curve
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(data3_norm)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('Elbow curv')
plt.xlabel('number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# selecting 4 clusters from above scree plot
model=KMeans(n_clusters=4)
model.fit(data3_norm)
model.labels_
# Out:
# array([1, 1, 1, ..., 3, 1, 1])

# %%
#Assign clusters to the data set
data3['clusterid_new'] = model.labels_

# %%
data3
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
data3.groupby('clusterid_new').mean()
# Out:
#                     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clusterid_new
# 0              28617.579670  112.000000   3.280220   1.030220   1.068681
# 1              88484.857577  175.062961   1.495441   1.008250   1.001737
# 2               5129.247934    8.285124   1.004132   1.004132   1.000000
# 3              72378.903670  119.606422   3.077982   1.024771   1.018349
#
#                 Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clusterid_new
# 0              42166.565934    17.634615         659.725275         1.909341
# 1               8110.131568     8.770734         476.973079         1.439427
# 2                891.388430     3.012397          66.466942         0.194215
# 3              31486.477982    17.476147         445.017431         1.317431
#
#                Days_since_enroll    Award?
# clusterid_new
# 0                    4229.689560  0.901099
# 1                    4060.013895  0.255319
# ...

# %% [markdown]
# # DBSCAN

# %%
data=pd.read_excel(r"C:\Users\DELL\Desktop\Data Science\DS Assignment\Clustering\EastWestAirlines.xlsx",'data')
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df=data.iloc[:,1:]
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df.values
# Out:
# array([[28143,     0,     1, ...,     0,  7000,     0],
#        [19244,     0,     1, ...,     0,  6968,     0],
#        [41354,     0,     1, ...,     0,  7034,     0],
#        ...,
#        [73597,     0,     3, ...,     0,  1402,     1],
#        [54899,     0,     1, ...,     1,  1401,     0],
#        [ 3016,     0,     1, ...,     0,  1398,     0]], dtype=int64)

# %%
stscaler=StandardScaler().fit(df.values)
x=stscaler.transform(df.values)
x
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
dbscan=DBSCAN(eps=2,min_samples=5)
dbscan.fit(x)
# Out:
# DBSCAN(eps=2)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
cl=pd.DataFrame(dbscan.labels_,columns=['cluster'])
cl
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# ...       ...
# 3994        1
# 3995        1
# 3996        1
# 3997        0
# 3998        0
#
# [3999 rows x 1 columns]

# %%
clustered = pd.concat([df, cl], axis = 1)

# %%
clustered
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
clustered[clustered['cluster'] == -1]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 8      443003           0          3          2          1         1753
# 50     108137           0          1          1          1         6368
# 65      53914           0          3          1          1        33767
# 70      84409        5031          2          1          1        15436
# 87     609477           0          3          1          1        21422
# ...       ...         ...        ...        ...        ...          ...
# 3846    97510        1678          5          1          1        71609
# 3883   126167           0          5          1          1       190160
# 3911    55922        2273          1          1          1         8104
# 3917   130748           0          4          1          1        65510
# 3934    76595           0          1          1          1        10577
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
clustered.mean()
# Out:
# Balance              73601.327582
# Qual_miles             144.114529
# cc1_miles                2.059515
# cc2_miles                1.014504
# cc3_miles                1.012253
# Bonus_miles          17144.846212
# Bonus_trans             11.601900
# Flight_miles_12mo      460.055764
# Flight_trans_12          1.373593
# Days_since_enroll     4118.559390
# Award?                   0.370343
# cluster                  0.315829
# dtype: float64

# %%
clustered.sort_values('cluster')
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 702    340874           0          5          1          1        68090
# 238     30962           0          5          1          1        97683
# 2656   644881        2600          1          1          1        14350
# 243    118934           0          5          1          1        66222
# 2375    92843           0          1          1          1        27650
# ...       ...         ...        ...        ...        ...          ...
# 1433   120152           0          1          1          1         6250
# 3105    58382           0          1          1          1        11327
# 1187   123646           0          1          1          1        12450
# 511      9800         589          1          1          1        10348
# 3082    54637           0          1          1          1        21181
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
x.shape
# Out:
# (3999, 11)
